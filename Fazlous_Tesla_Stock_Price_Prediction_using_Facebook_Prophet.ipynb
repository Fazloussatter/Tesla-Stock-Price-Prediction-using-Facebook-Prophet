# %% [markdown]
# <a href="https://colab.research.google.com/github/Fazloussatter/Tesla-Stock-Price-Prediction-using-Facebook-Prophet/blob/main/Fazlous_Tesla_Stock_Price_Prediction_using_Facebook_Prophet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tesla Stock Price Prediction using Facebook Prophet

# %% [markdown]
# ###Importing essential packages

# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
# Initializing the plotly
import plotly.io as pio
pio.renderers.default='colab'

# %% [markdown]
# ### Importing the dataset

# %%
df=pd.read_csv('TSLA.csv')

# %% [markdown]
# ### Now checking a few rows of the dataset

# %%
df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2020-03-16  31.299999  32.991333  29.478001  29.671333  29.671333
# 1  2020-03-17  29.334000  31.456667  26.400000  28.680000  28.680000
# 2  2020-03-18  25.933332  26.990667  23.367332  24.081333  24.081333
# 3  2020-03-19  24.980000  30.133333  23.897333  28.509333  28.509333
# 4  2020-03-20  29.213333  31.799999  28.386000  28.502001  28.502001
#
#       Volume
# 0  307342500
# 1  359919000
# 2  356793000
# 3  452932500
# 4  424282500

# %% [markdown]
# ### Gathering basic information about the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251 entries, 0 to 250
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       251 non-null    object
#  1   Open       251 non-null    float64
#  2   High       251 non-null    float64
#  3   Low        251 non-null    float64
#  4   Close      251 non-null    float64
#  5   Adj Close  251 non-null    float64
#  6   Volume     251 non-null    int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 13.9+ KB

# %% [markdown]
# ### Gathering descriptive statistics about the data

# %%
df.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  251.000000  251.000000  251.000000  251.000000  251.000000
# mean   138.246369  141.774422  134.254906  138.379317  138.379317
# std     78.302853   79.791610   76.367220   78.329273   78.329273
# min     24.980000   26.990667   23.367332   24.081333   24.081333
# 25%     64.967003   66.461334   62.855667   64.456333   64.456333
# 50%    136.317337  139.566666  133.886673  136.166672  136.166672
# 75%    202.183334  209.264999  195.583336  202.411667  202.411667
# max    297.126678  300.133331  290.533325  294.363342  294.363342
#
#              Volume
# count  2.510000e+02
# mean   1.853566e+08
# std    9.918383e+07
# min    4.547310e+07
# 25%    1.088487e+08
# 50%    1.668480e+08
# 75%    2.439548e+08
# max    6.663786e+08

# %% [markdown]
# ### Visualizing the historical performance of Tesla

# %%
# Creating an Area Chart

px.area(df, x='Date',y='Close')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Let's examine this price hike with a Line chart
px.line(df, x='Date',y='Close')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Now checking the volume by an Area Chat
px.area(df, x='Date',y='Volume')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Now rechecking it again with a Bar Chart
px.bar(df,y='Volume')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Now, checking the distribution with a Box Plot
px.box(df,y='Close')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Again checking the dataframe

# %%
df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2020-03-16  31.299999  32.991333  29.478001  29.671333  29.671333
# 1  2020-03-17  29.334000  31.456667  26.400000  28.680000  28.680000
# 2  2020-03-18  25.933332  26.990667  23.367332  24.081333  24.081333
# 3  2020-03-19  24.980000  30.133333  23.897333  28.509333  28.509333
# 4  2020-03-20  29.213333  31.799999  28.386000  28.502001  28.502001
#
#       Volume
# 0  307342500
# 1  359919000
# 2  356793000
# 3  452932500
# 4  424282500

# %% [markdown]
# ### Seecting the columns and creating a new dataframe

# %%
columns=['Date', 'Close']
ndf=pd.DataFrame(df, columns=columns)

# %% [markdown]
# ### Now checking the new dataframe

# %%
ndf
# Out:
#            Date       Close
# 0    2020-03-16   29.671333
# 1    2020-03-17   28.680000
# 2    2020-03-18   24.081333
# 3    2020-03-19   28.509333
# 4    2020-03-20   28.502001
# ..          ...         ...
# 246  2021-03-08  187.666672
# 247  2021-03-09  224.526672
# 248  2021-03-10  222.686661
# 249  2021-03-11  233.199997
# 250  2021-03-12  231.243332
#
# [251 rows x 2 columns]

# %% [markdown]
#  ### Now installing and importing FB Prophet for forecasting

# %%
# !pip install prophet
from prophet import Prophet

# %% [markdown]
# ### Renaming columns for the forecasting the price ups and down

# %%
Prophet_df=ndf.rename(columns={'Date':'ds', 'Close':'y'})
Prophet_df
# Out:
#              ds           y
# 0    2020-03-16   29.671333
# 1    2020-03-17   28.680000
# 2    2020-03-18   24.081333
# 3    2020-03-19   28.509333
# 4    2020-03-20   28.502001
# ..          ...         ...
# 246  2021-03-08  187.666672
# 247  2021-03-09  224.526672
# 248  2021-03-10  222.686661
# 249  2021-03-11  233.199997
# 250  2021-03-12  231.243332
#
# [251 rows x 2 columns]

# %% [markdown]
# ## Creating Facebook Prophet Model

# %%
m=Prophet()
m.fit(Prophet_df)
# Out:
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp9fb57a3w/ok1txuye.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp9fb57a3w/256x7bnw.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=30583', 'data', 'file=/tmp/tmp9fb57a3w/ok1txuye.json', 'init=/tmp/tmp9fb57a3w/256x7bnw.json', 'output', 'file=/tmp/tmp9fb57a3w/prophet_model34048s0b/prophet_model-20240315091159.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:11:59 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:11:59 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %% [markdown]
# ### Forecasting/ prediction on Facebook prophet

# %%
future=m.make_future_dataframe(periods=60)
forecast=m.predict(future)
forecast
# Out:
#             ds       trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0   2020-03-16   21.803169   -8.978100   47.337102    21.803169    21.803169
# 1   2020-03-17   22.402317   -5.932902   50.347766    22.402317    22.402317
# 2   2020-03-18   23.001466   -7.372873   49.954067    23.001466    23.001466
# 3   2020-03-19   23.600614   -5.752171   49.163976    23.600614    23.600614
# 4   2020-03-20   24.199763   -8.339523   49.176313    24.199763    24.199763
# ..         ...         ...         ...         ...          ...          ...
# 306 2021-05-07  324.517367  290.809330  349.381566   323.088229   325.730638
# 307 2021-05-08  325.335082  301.655048  357.672468   323.860860   326.573323
# 308 2021-05-09  326.152796  301.256943  356.807523   324.644109   327.430810
# 309 2021-05-10  326.970510  296.491748  354.098514   325.417199   328.292225
# 310 2021-05-11  327.788224  298.177548  355.110117   326.199700   329.145497
#
# ...

# %% [markdown]
# ### As the column is most importan, so we are now creating a Line Chart with that.

# %%
px.line(forecast, x='ds', y='yhat')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
figure=m.plot(forecast, xlabel='ds', ylabel='y')

# %% [markdown]
# ### Importing matplotlib to observe the various components

# %%
import matplotlib.pyplot as plt
figure2=m.plot_components(forecast)

# %% [markdown]
# ### Downloading the forecast data as a csv file

# %%
from google.colab import files
forecast.to_csv('forecast.csv')
files.download('forecast.csv')
